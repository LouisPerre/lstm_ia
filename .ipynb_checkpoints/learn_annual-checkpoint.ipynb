# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
from torch.utils.tensorboard import SummaryWriter
writer = SummaryWriter(log_dir="runs/AAPL_stock_prediction_2")

data = pd.read_csv('annual_aapl_data.csv')

data
# Out:
# Package                      Version        Location                                                                               Installer
# ---------------------------- -------------- -------------------------------------------------------------------------------------- ---------
# absl-py                      2.1.0          /Users/louisperrenot/projet_docker/perso/IA2/lstm_iim/venv/lib/python3.9/site-packages pip
# anyio                        4.6.2.post1    /Users/louisperrenot/projet_docker/perso/IA2/lstm_iim/venv/lib/python3.9/site-packages pip
# appnope                      0.1.4          /Users/louisperrenot/projet_docker/perso/IA2/lstm_iim/venv/lib/python3.9/site-packages pip
# argon2-cffi                  23.1.0         /Users/louisperrenot/projet_docker/perso/IA2/lstm_iim/venv/lib/python3.9/site-packages pip
# argon2-cffi-bindings         21.2.0         /Users/louisperrenot/projet_docker/perso/IA2/lstm_iim/venv/lib/python3.9/site-packages pip
# arrow                        1.3.0          /Users/louisperrenot/projet_docker/perso/IA2/lstm_iim/venv/lib/python3.9/site-packages pip
# asttokens                    2.4.1          /Users/louisperrenot/projet_docker/perso/IA2/lstm_iim/venv/lib/python3.9/site-packages pip
# astunparse                   1.6.3          /Users/louisperrenot/projet_docker/perso/IA2/lstm_iim/venv/lib/python3.9/site-packages pip
# async-lru                    2.0.4          /Users/louisperrenot/projet_docker/perso/IA2/lstm_iim/venv/lib/python3.9/site-packages pip
# attrs                        24.2.0         /Users/louisperrenot/projet_docker/perso/IA2/lstm_iim/venv/lib/python3.9/site-packages pip
# babel                        2.16.0         /Users/louisperrenot/projet_docker/perso/IA2/lstm_iim/venv/lib/python3.9/site-packages pip
# beautifulsoup4               4.12.3         /Users/louisperrenot/projet_docker/perso/IA2/lstm_iim/venv/lib/python3.9/site-packages pip
# bleach                       6.2.0          /Users/louisperrenot/projet_docker/perso/IA2/lstm_iim/venv/lib/python3.9/site-packages pip
# certifi                      2024.8.30      /Users/louisperrenot/projet_docker/perso/IA2/lstm_iim/venv/lib/python3.9/site-packages pip
# cffi                         1.17.1         /Users/louisperrenot/projet_docker/perso/IA2/lstm_iim/venv/lib/python3.9/site-packages pip
# charset-normalizer           3.4.0          /Users/louisperrenot/projet_docker/perso/IA2/lstm_iim/venv/lib/python3.9/site-packages pip
# comm                         0.2.2          /Users/louisperrenot/projet_docker/perso/IA2/lstm_iim/venv/lib/python3.9/site-packages pip
# contourpy                    1.3.0          /Users/louisperrenot/projet_docker/perso/IA2/lstm_iim/venv/lib/python3.9/site-packages pip
# cycler                       0.12.1         /Users/louisperrenot/projet_docker/perso/IA2/lstm_iim/venv/lib/python3.9/site-packages pip
# debugpy                      1.8.8          /Users/louisperrenot/projet_docker/perso/IA2/lstm_iim/venv/lib/python3.9/site-packages pip
# decorator                    5.1.1          /Users/louisperrenot/projet_docker/perso/IA2/lstm_iim/venv/lib/python3.9/site-packages pip
# defusedxml                   0.7.1          /Users/louisperrenot/projet_docker/perso/IA2/lstm_iim/venv/lib/python3.9/site-packages pip
# exceptiongroup               1.2.2          /Users/louisperrenot/projet_docker/perso/IA2/lstm_iim/venv/lib/python3.9/site-packages pip
# executing                    2.1.0          /Users/louisperrenot/projet_docker/perso/IA2/lstm_iim/venv/lib/python3.9/site-packages pip
# fastjsonschema               2.20.0         /Users/louisperrenot/projet_docker/perso/IA2/lstm_iim/venv/lib/python3.9/site-packages pip
# filelock                     3.16.1         /Users/louisperrenot/projet_docker/perso/IA2/lstm_iim/venv/lib/python3.9/site-packages pip
# flatbuffers                  24.3.25        /Users/louisperrenot/projet_docker/perso/IA2/lstm_iim/venv/lib/python3.9/site-packages pip
# fonttools                    4.55.0         /Users/louisperrenot/projet_docker/perso/IA2/lstm_iim/venv/lib/python3.9/site-packages pip
# fqdn                         1.5.1          /Users/louisperrenot/projet_docker/perso/IA2/lstm_iim/venv/lib/python3.9/site-packages pip
# frozendict                   2.4.6          /Users/louisperrenot/projet_docker/perso/IA2/lstm_iim/venv/lib/python3.9/site-packages pip
# fsspec                       2024.10.0      /Users/louisperrenot/projet_docker/perso/IA2/lstm_iim/venv/lib/python3.9/site-packages pip
# gast                         0.6.0          /Users/louisperrenot/projet_docker/perso/IA2/lstm_iim/venv/lib/python3.9/site-packages pip
# google-pasta                 0.2.0          /Users/louisperrenot/projet_docker/perso/IA2/lstm_iim/venv/lib/python3.9/site-packages pip
# grpcio                       1.68.0         /Users/louisperrenot/projet_docker/perso/IA2/lstm_iim/venv/lib/python3.9/site-packages pip
# h11                          0.14.0         /Users/louisperrenot/projet_docker/perso/IA2/lstm_iim/venv/lib/python3.9/site-packages pip
# h5py                         3.12.1         /Users/louisperrenot/projet_docker/perso/IA2/lstm_iim/venv/lib/python3.9/site-packages pip
# html5lib                     1.1            /Users/louisperrenot/projet_docker/perso/IA2/lstm_iim/venv/lib/python3.9/site-packages pip
# httpcore                     1.0.7          /Users/louisperrenot/projet_docker/perso/IA2/lstm_iim/venv/lib/python3.9/site-packages pip
# httpx                        0.27.2         /Users/louisperrenot/projet_docker/perso/IA2/lstm_iim/venv/lib/python3.9/site-packages pip
# idna                         3.10           /Users/louisperrenot/projet_docker/perso/IA2/lstm_iim/venv/lib/python3.9/site-packages pip
# importlib_metadata           8.5.0          /Users/louisperrenot/projet_docker/perso/IA2/lstm_iim/venv/lib/python3.9/site-packages pip
# importlib_resources          6.4.5          /Users/louisperrenot/projet_docker/perso/IA2/lstm_iim/venv/lib/python3.9/site-packages pip
# ipykernel                    6.29.5         /Users/louisperrenot/projet_docker/perso/IA2/lstm_iim/venv/lib/python3.9/site-packages pip
# ipython                      8.18.1         /Users/louisperrenot/projet_docker/perso/IA2/lstm_iim/venv/lib/python3.9/site-packages pip
# isoduration                  20.11.0        /Users/louisperrenot/projet_docker/perso/IA2/lstm_iim/venv/lib/python3.9/site-packages pip
# jedi                         0.19.2         /Users/louisperrenot/projet_docker/perso/IA2/lstm_iim/venv/lib/python3.9/site-packages pip
# Jinja2                       3.1.4          /Users/louisperrenot/projet_docker/perso/IA2/lstm_iim/venv/lib/python3.9/site-packages pip
# joblib                       1.4.2          /Users/louisperrenot/projet_docker/perso/IA2/lstm_iim/venv/lib/python3.9/site-packages pip
# json5                        0.9.28         /Users/louisperrenot/projet_docker/perso/IA2/lstm_iim/venv/lib/python3.9/site-packages pip
# jsonpointer                  3.0.0          /Users/louisperrenot/projet_docker/perso/IA2/lstm_iim/venv/lib/python3.9/site-packages pip
# jsonschema                   4.23.0         /Users/louisperrenot/projet_docker/perso/IA2/lstm_iim/venv/lib/python3.9/site-packages pip
# jsonschema-specifications    2024.10.1      /Users/louisperrenot/projet_docker/perso/IA2/lstm_iim/venv/lib/python3.9/site-packages pip
# jupyter_client               8.6.3          /Users/louisperrenot/projet_docker/perso/IA2/lstm_iim/venv/lib/python3.9/site-packages pip
# jupyter_core                 5.7.2          /Users/louisperrenot/projet_docker/perso/IA2/lstm_iim/venv/lib/python3.9/site-packages pip
# jupyter-events               0.10.0         /Users/louisperrenot/projet_docker/perso/IA2/lstm_iim/venv/lib/python3.9/site-packages pip
# jupyter-lsp                  2.2.5          /Users/louisperrenot/projet_docker/perso/IA2/lstm_iim/venv/lib/python3.9/site-packages pip
# jupyter_server               2.14.2         /Users/louisperrenot/projet_docker/perso/IA2/lstm_iim/venv/lib/python3.9/site-packages pip
# jupyter_server_terminals     0.5.3          /Users/louisperrenot/projet_docker/perso/IA2/lstm_iim/venv/lib/python3.9/site-packages pip
# jupyterlab                   4.2.6          /Users/louisperrenot/projet_docker/perso/IA2/lstm_iim/venv/lib/python3.9/site-packages pip
# jupyterlab_pygments          0.3.0          /Users/louisperrenot/projet_docker/perso/IA2/lstm_iim/venv/lib/python3.9/site-packages pip
# jupyterlab_server            2.27.3         /Users/louisperrenot/projet_docker/perso/IA2/lstm_iim/venv/lib/python3.9/site-packages pip
# keras                        3.6.0          /Users/louisperrenot/projet_docker/perso/IA2/lstm_iim/venv/lib/python3.9/site-packages pip
# kiwisolver                   1.4.7          /Users/louisperrenot/projet_docker/perso/IA2/lstm_iim/venv/lib/python3.9/site-packages pip
# libclang                     18.1.1         /Users/louisperrenot/projet_docker/perso/IA2/lstm_iim/venv/lib/python3.9/site-packages pip
# lxml                         5.3.0          /Users/louisperrenot/projet_docker/perso/IA2/lstm_iim/venv/lib/python3.9/site-packages pip
# Markdown                     3.7            /Users/louisperrenot/projet_docker/perso/IA2/lstm_iim/venv/lib/python3.9/site-packages pip
# markdown-it-py               3.0.0          /Users/louisperrenot/projet_docker/perso/IA2/lstm_iim/venv/lib/python3.9/site-packages pip
# MarkupSafe                   3.0.2          /Users/louisperrenot/projet_docker/perso/IA2/lstm_iim/venv/lib/python3.9/site-packages pip
# matplotlib                   3.9.2          /Users/louisperrenot/projet_docker/perso/IA2/lstm_iim/venv/lib/python3.9/site-packages pip
# matplotlib-inline            0.1.7          /Users/louisperrenot/projet_docker/perso/IA2/lstm_iim/venv/lib/python3.9/site-packages pip
# mdurl                        0.1.2          /Users/louisperrenot/projet_docker/perso/IA2/lstm_iim/venv/lib/python3.9/site-packages pip
# mistune                      3.0.2          /Users/louisperrenot/projet_docker/perso/IA2/lstm_iim/venv/lib/python3.9/site-packages pip
# ml-dtypes                    0.4.1          /Users/louisperrenot/projet_docker/perso/IA2/lstm_iim/venv/lib/python3.9/site-packages pip
# mpmath                       1.3.0          /Users/louisperrenot/projet_docker/perso/IA2/lstm_iim/venv/lib/python3.9/site-packages pip
# multitasking                 0.0.11         /Users/louisperrenot/projet_docker/perso/IA2/lstm_iim/venv/lib/python3.9/site-packages pip
# namex                        0.0.8          /Users/louisperrenot/projet_docker/perso/IA2/lstm_iim/venv/lib/python3.9/site-packages pip
# nbclient                     0.10.0         /Users/louisperrenot/projet_docker/perso/IA2/lstm_iim/venv/lib/python3.9/site-packages pip
# nbconvert                    7.16.4         /Users/louisperrenot/projet_docker/perso/IA2/lstm_iim/venv/lib/python3.9/site-packages pip
# nbformat                     5.10.4         /Users/louisperrenot/projet_docker/perso/IA2/lstm_iim/venv/lib/python3.9/site-packages pip
# nest-asyncio                 1.6.0          /Users/louisperrenot/projet_docker/perso/IA2/lstm_iim/venv/lib/python3.9/site-packages pip
# networkx                     3.2.1          /Users/louisperrenot/projet_docker/perso/IA2/lstm_iim/venv/lib/python3.9/site-packages pip
# notebook                     7.2.2          /Users/louisperrenot/projet_docker/perso/IA2/lstm_iim/venv/lib/python3.9/site-packages pip
# notebook_shim                0.2.4          /Users/louisperrenot/projet_docker/perso/IA2/lstm_iim/venv/lib/python3.9/site-packages pip
# numpy                        2.0.2          /Users/louisperrenot/projet_docker/perso/IA2/lstm_iim/venv/lib/python3.9/site-packages pip
# opt_einsum                   3.4.0          /Users/louisperrenot/projet_docker/perso/IA2/lstm_iim/venv/lib/python3.9/site-packages pip
# optree                       0.13.1         /Users/louisperrenot/projet_docker/perso/IA2/lstm_iim/venv/lib/python3.9/site-packages pip
# overrides                    7.7.0          /Users/louisperrenot/projet_docker/perso/IA2/lstm_iim/venv/lib/python3.9/site-packages pip
# packaging                    24.2           /Users/louisperrenot/projet_docker/perso/IA2/lstm_iim/venv/lib/python3.9/site-packages pip
# pandas                       2.2.3          /Users/louisperrenot/projet_docker/perso/IA2/lstm_iim/venv/lib/python3.9/site-packages pip
# pandas-datareader            0.10.0         /Users/louisperrenot/projet_docker/perso/IA2/lstm_iim/venv/lib/python3.9/site-packages pip
# pandocfilters                1.5.1          /Users/louisperrenot/projet_docker/perso/IA2/lstm_iim/venv/lib/python3.9/site-packages pip
# parso                        0.8.4          /Users/louisperrenot/projet_docker/perso/IA2/lstm_iim/venv/lib/python3.9/site-packages pip
# peewee                       3.17.8         /Users/louisperrenot/projet_docker/perso/IA2/lstm_iim/venv/lib/python3.9/site-packages pip
# pexpect                      4.9.0          /Users/louisperrenot/projet_docker/perso/IA2/lstm_iim/venv/lib/python3.9/site-packages pip
# pillow                       11.0.0         /Users/louisperrenot/projet_docker/perso/IA2/lstm_iim/venv/lib/python3.9/site-packages pip
# pip                          24.2           /Users/louisperrenot/projet_docker/perso/IA2/lstm_iim/venv/lib/python3.9/site-packages pip
# platformdirs                 4.3.6          /Users/louisperrenot/projet_docker/perso/IA2/lstm_iim/venv/lib/python3.9/site-packages pip
# prometheus_client            0.21.0         /Users/louisperrenot/projet_docker/perso/IA2/lstm_iim/venv/lib/python3.9/site-packages pip
# prompt_toolkit               3.0.48         /Users/louisperrenot/projet_docker/perso/IA2/lstm_iim/venv/lib/python3.9/site-packages pip
# protobuf                     5.28.3         /Users/louisperrenot/projet_docker/perso/IA2/lstm_iim/venv/lib/python3.9/site-packages pip
# psutil                       6.1.0          /Users/louisperrenot/projet_docker/perso/IA2/lstm_iim/venv/lib/python3.9/site-packages pip
# ptyprocess                   0.7.0          /Users/louisperrenot/projet_docker/perso/IA2/lstm_iim/venv/lib/python3.9/site-packages pip
# pure_eval                    0.2.3          /Users/louisperrenot/projet_docker/perso/IA2/lstm_iim/venv/lib/python3.9/site-packages pip
# pycparser                    2.22           /Users/louisperrenot/projet_docker/perso/IA2/lstm_iim/venv/lib/python3.9/site-packages pip
# Pygments                     2.18.0         /Users/louisperrenot/projet_docker/perso/IA2/lstm_iim/venv/lib/python3.9/site-packages pip
# pyparsing                    3.2.0          /Users/louisperrenot/projet_docker/perso/IA2/lstm_iim/venv/lib/python3.9/site-packages pip
# python-dateutil              2.9.0.post0    /Users/louisperrenot/projet_docker/perso/IA2/lstm_iim/venv/lib/python3.9/site-packages pip
# python-json-logger           2.0.7          /Users/louisperrenot/projet_docker/perso/IA2/lstm_iim/venv/lib/python3.9/site-packages pip
# pytz                         2024.2         /Users/louisperrenot/projet_docker/perso/IA2/lstm_iim/venv/lib/python3.9/site-packages pip
# PyYAML                       6.0.2          /Users/louisperrenot/projet_docker/perso/IA2/lstm_iim/venv/lib/python3.9/site-packages pip
# pyzmq                        26.2.0         /Users/louisperrenot/projet_docker/perso/IA2/lstm_iim/venv/lib/python3.9/site-packages pip
# referencing                  0.35.1         /Users/louisperrenot/projet_docker/perso/IA2/lstm_iim/venv/lib/python3.9/site-packages pip
# requests                     2.32.3         /Users/louisperrenot/projet_docker/perso/IA2/lstm_iim/venv/lib/python3.9/site-packages pip
# rfc3339-validator            0.1.4          /Users/louisperrenot/projet_docker/perso/IA2/lstm_iim/venv/lib/python3.9/site-packages pip
# rfc3986-validator            0.1.1          /Users/louisperrenot/projet_docker/perso/IA2/lstm_iim/venv/lib/python3.9/site-packages pip
# rich                         13.9.4         /Users/louisperrenot/projet_docker/perso/IA2/lstm_iim/venv/lib/python3.9/site-packages pip
# rpds-py                      0.21.0         /Users/louisperrenot/projet_docker/perso/IA2/lstm_iim/venv/lib/python3.9/site-packages pip
# scikit-learn                 1.5.2          /Users/louisperrenot/projet_docker/perso/IA2/lstm_iim/venv/lib/python3.9/site-packages pip
# scipy                        1.13.1         /Users/louisperrenot/projet_docker/perso/IA2/lstm_iim/venv/lib/python3.9/site-packages pip
# seaborn                      0.13.2         /Users/louisperrenot/projet_docker/perso/IA2/lstm_iim/venv/lib/python3.9/site-packages pip
# Send2Trash                   1.8.3          /Users/louisperrenot/projet_docker/perso/IA2/lstm_iim/venv/lib/python3.9/site-packages pip
# setuptools                   74.1.2         /Users/louisperrenot/projet_docker/perso/IA2/lstm_iim/venv/lib/python3.9/site-packages pip
# six                          1.16.0         /Users/louisperrenot/projet_docker/perso/IA2/lstm_iim/venv/lib/python3.9/site-packages pip
# sniffio                      1.3.1          /Users/louisperrenot/projet_docker/perso/IA2/lstm_iim/venv/lib/python3.9/site-packages pip
# soupsieve                    2.6            /Users/louisperrenot/projet_docker/perso/IA2/lstm_iim/venv/lib/python3.9/site-packages pip
# stack-data                   0.6.3          /Users/louisperrenot/projet_docker/perso/IA2/lstm_iim/venv/lib/python3.9/site-packages pip
# sympy                        1.13.1         /Users/louisperrenot/projet_docker/perso/IA2/lstm_iim/venv/lib/python3.9/site-packages pip
# tabulate                     0.9.0          /Users/louisperrenot/projet_docker/perso/IA2/lstm_iim/venv/lib/python3.9/site-packages pip
# tensorboard                  2.18.0         /Users/louisperrenot/projet_docker/perso/IA2/lstm_iim/venv/lib/python3.9/site-packages pip
# tensorboard-data-server      0.7.2          /Users/louisperrenot/projet_docker/perso/IA2/lstm_iim/venv/lib/python3.9/site-packages pip
# tensorflow                   2.18.0         /Users/louisperrenot/projet_docker/perso/IA2/lstm_iim/venv/lib/python3.9/site-packages pip
# tensorflow-io-gcs-filesystem 0.37.1         /Users/louisperrenot/projet_docker/perso/IA2/lstm_iim/venv/lib/python3.9/site-packages pip
# termcolor                    2.5.0          /Users/louisperrenot/projet_docker/perso/IA2/lstm_iim/venv/lib/python3.9/site-packages pip
# terminado                    0.18.1         /Users/louisperrenot/projet_docker/perso/IA2/lstm_iim/venv/lib/python3.9/site-packages pip
# threadpoolctl                3.5.0          /Users/louisperrenot/projet_docker/perso/IA2/lstm_iim/venv/lib/python3.9/site-packages pip
# tinycss2                     1.4.0          /Users/louisperrenot/projet_docker/perso/IA2/lstm_iim/venv/lib/python3.9/site-packages pip
# tomli                        2.1.0          /Users/louisperrenot/projet_docker/perso/IA2/lstm_iim/venv/lib/python3.9/site-packages pip
# torch                        2.5.1          /Users/louisperrenot/projet_docker/perso/IA2/lstm_iim/venv/lib/python3.9/site-packages pip
# torchaudio                   2.5.1          /Users/louisperrenot/projet_docker/perso/IA2/lstm_iim/venv/lib/python3.9/site-packages pip
# torchvision                  0.20.1         /Users/louisperrenot/projet_docker/perso/IA2/lstm_iim/venv/lib/python3.9/site-packages pip
# tornado                      6.4.1          /Users/louisperrenot/projet_docker/perso/IA2/lstm_iim/venv/lib/python3.9/site-packages pip
# traitlets                    5.14.3         /Users/louisperrenot/projet_docker/perso/IA2/lstm_iim/venv/lib/python3.9/site-packages pip
# types-python-dateutil        2.9.0.20241003 /Users/louisperrenot/projet_docker/perso/IA2/lstm_iim/venv/lib/python3.9/site-packages pip
# typing_extensions            4.12.2         /Users/louisperrenot/projet_docker/perso/IA2/lstm_iim/venv/lib/python3.9/site-packages pip
# tzdata                       2024.2         /Users/louisperrenot/projet_docker/perso/IA2/lstm_iim/venv/lib/python3.9/site-packages pip
# uri-template                 1.3.0          /Users/louisperrenot/projet_docker/perso/IA2/lstm_iim/venv/lib/python3.9/site-packages pip
# urllib3                      1.26.15        /Users/louisperrenot/projet_docker/perso/IA2/lstm_iim/venv/lib/python3.9/site-packages pip
# wcwidth                      0.2.13         /Users/louisperrenot/projet_docker/perso/IA2/lstm_iim/venv/lib/python3.9/site-packages pip
# webcolors                    24.11.1        /Users/louisperrenot/projet_docker/perso/IA2/lstm_iim/venv/lib/python3.9/site-packages pip
# webencodings                 0.5.1          /Users/louisperrenot/projet_docker/perso/IA2/lstm_iim/venv/lib/python3.9/site-packages pip
# websocket-client             1.8.0          /Users/louisperrenot/projet_docker/perso/IA2/lstm_iim/venv/lib/python3.9/site-packages pip
# Werkzeug                     3.1.3          /Users/louisperrenot/projet_docker/perso/IA2/lstm_iim/venv/lib/python3.9/site-packages pip
# wheel                        0.45.0         /Users/louisperrenot/projet_docker/perso/IA2/lstm_iim/venv/lib/python3.9/site-packages pip
# wrapt                        1.16.0         /Users/louisperrenot/projet_docker/perso/IA2/lstm_iim/venv/lib/python3.9/site-packages pip
# yfinance                     0.2.50         /Users/louisperrenot/projet_docker/perso/IA2/lstm_iim/venv/lib/python3.9/site-packages pip
# zipp                         3.21.0         /Users/louisperrenot/projet_docker/perso/IA2/lstm_iim/venv/lib/python3.9/site-packages pip
#     Year-Month  start_price   end_price  total_dividends     return
# 0      1980-12     0.128348    0.117313             0.00  -8.598017
# 1      1981-01     0.154018    0.097116             0.00 -36.945201
# 2      1981-02     0.119420    0.091100             0.00 -23.714527
# 3      1981-03     0.118862    0.084224             0.00 -29.141120
# 4      1981-04     0.108817    0.097545             0.00 -10.358331
# ..         ...          ...         ...              ...        ...
# 522    2024-06   192.899994  210.145279             0.00   8.940013
# 523    2024-07   212.089996  221.579468             0.00   4.474266
# 524    2024-08   224.369995  228.748337             0.25   2.062817
# 525    2024-09   228.550003  232.743942             0.00   1.835020
# 526    2024-10   229.520004  225.661728             0.00  -1.681020
#
# [527 rows x 5 columns]

# %%
data = data[['Year-Month', 'return']]
data
# Out:
#     Year-Month     return
# 0      1980-12  -8.598017
# 1      1981-01 -36.945201
# 2      1981-02 -23.714527
# 3      1981-03 -29.141120
# 4      1981-04 -10.358331
# ..         ...        ...
# 522    2024-06   8.940013
# 523    2024-07   4.474266
# 524    2024-08   2.062817
# 525    2024-09   1.835020
# 526    2024-10  -1.681020
#
# [527 rows x 2 columns]

# %%
device = 'cuda:0' if torch.cuda.is_available() else 'mps'
device
# Out:
# 'mps'

# %%
# Transform to a panda date type
data['Year-Month'] = pd.to_datetime(data['Year-Month'], format='%Y-%m')
# Do a graph of the closing value with the date
plt.plot(data['Year-Month'], data['return'])
plt.xlabel('Year-Month')
plt.ylabel('Return')
plt.title('Annual Returns Over Time')
plt.show()
# Out:
# /var/folders/8t/zq98g53s2rs8x1qgc3h02m100000gn/T/ipykernel_22093/2340483137.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Year-Month'] = pd.to_datetime(data['Year-Month'], format='%Y-%m')

# %%
from copy import deepcopy as dc

# Take the dataframes and the number (look back window)
def prepare_dataframe_for_lstm(df, n_steps):
    # Deep copy of the dataframe
    df = dc(df)
    # Set the index to Date
    df.set_index('Year-Month', inplace=True)

    for i in range(1, n_steps + 1):
        df[f'return(t-{i})'] = df['return'].shift(i)

    df.dropna(inplace=True)

    return df

lookback = 5
shifted_df = prepare_dataframe_for_lstm(data, lookback)
shifted_df
# Out:
#                return  return(t-1)  return(t-2)  return(t-3)  return(t-4)  \
# Year-Month
# 1981-05-01 -10.104385   -10.358331   -29.141120   -23.714527   -36.945201
# 1981-06-01 -39.558310   -10.104385   -10.358331   -29.141120   -23.714527
# 1981-07-01 -25.598772   -39.558310   -10.104385   -10.358331   -29.141120
# 1981-08-01 -38.010618   -25.598772   -39.558310   -10.104385   -10.358331
# 1981-09-01 -45.060918   -38.010618   -25.598772   -39.558310   -10.104385
# ...               ...          ...          ...          ...          ...
# 2024-06-01   8.940013    13.260219    -0.861084    -4.838901    -1.984715
# 2024-07-01   4.474266     8.940013    13.260219    -0.861084    -4.838901
# 2024-08-01   2.062817     4.474266     8.940013    13.260219    -0.861084
# 2024-09-01   1.835020     2.062817     4.474266     8.940013    13.260219
# 2024-10-01  -1.681020     1.835020     2.062817     4.474266     8.940013
#
#             return(t-5)
# Year-Month
# 1981-05-01    -8.598017
# 1981-06-01   -36.945201
# 1981-07-01   -23.714527
# 1981-08-01   -29.141120
# 1981-09-01   -10.358331
# ...                 ...
# 2024-06-01    -1.949758
# 2024-07-01    -1.984715
# 2024-08-01    -4.838901
# 2024-09-01    -0.861084
# 2024-10-01    13.260219
#
# [522 rows x 6 columns]

# %%
# Convert the data to numpy format
shifted_df_as_np = shifted_df.to_numpy()

shifted_df_as_np
# Out:
# array([[-10.10438483, -10.35833131, -29.14112037, -23.71452684,
#         -36.945201  ,  -8.59801739],
#        [-39.5583098 , -10.10438483, -10.35833131, -29.14112037,
#         -23.71452684, -36.945201  ],
#        [-25.59877223, -39.5583098 , -10.10438483, -10.35833131,
#         -29.14112037, -23.71452684],
#        ...,
#        [  2.06281668,   4.4742664 ,   8.94001326,  13.26021868,
#          -0.8610845 ,  -4.83890144],
#        [  1.83502041,   2.06281668,   4.4742664 ,   8.94001326,
#          13.26021868,  -0.8610845 ],
#        [ -1.68101965,   1.83502041,   2.06281668,   4.4742664 ,
#           8.94001326,  13.26021868]])

# %%
# Count the number of rows and column
shifted_df_as_np.shape
# Out:
# (522, 6)

# %%
class CustomMinMaxScaler:
    def __init__(self, min_val=-1, max_val=1, manual_max=None, increase_ratio=0.5):
        """
        Arguments:
        - min_val: La nouvelle valeur minimale pour la normalisation (par défaut -1).
        - max_val: La nouvelle valeur maximale pour la normalisation (par défaut 1).
        - manual_max: Si fourni, remplace le max calculé automatiquement du tableau.
        - increase_ratio: Si manual_max est None, augmente le max d'origine par ce ratio.
        """
        self.min_val = min_val
        self.max_val = max_val
        self.manual_max = manual_max
        self.increase_ratio = increase_ratio
        self.data_min_ = None
        self.data_max_ = None

    def fit(self, data):
        """Calcule les valeurs min et max nécessaires pour le scaling."""
        self.data_min_ = data.min()
        self.data_max_ = data.max()

        # Définir le max à utiliser
        if self.manual_max is not None:
            self.scaled_max_ = self.manual_max
        else:
            self.scaled_max_ = self.data_max_ * (1 + self.increase_ratio)
    
    def transform(self, data):
        """Applique la transformation min-max aux données."""
        if self.data_min_ is None or self.data_max_ is None:
            raise ValueError("The scaler has not been fitted yet.")
        
        # Transformation à la plage [min_val, max_val]
        scaled = (data - self.data_min_) / (self.scaled_max_ - self.data_min_)
        return scaled * (self.max_val - self.min_val) + self.min_val

    def inverse_transform(self, scaled_data):
        """Inverse la transformation pour revenir à l'échelle d'origine."""
        if self.data_min_ is None or self.scaled_max_ is None:
            raise ValueError("The scaler has not been fitted yet.")
        
        # Inverser la transformation
        original = (scaled_data - self.min_val) / (self.max_val - self.min_val)
        return original * (self.scaled_max_ - self.data_min_) + self.data_min_
    
    def fit_transform(self, data):
        """Combine fit et transform."""
        self.fit(data)
        return self.transform(data)

# %%
# Scaler on all the data
from sklearn.preprocessing import MinMaxScaler
# scaler = CustomMinMaxScaler(min_val=-1, max_val=1, increase_ratio=0.5)
# shifted_df_as_np = scaler.fit_transform(shifted_df_as_np)
# Transform the numpy value from above to -1, 1
scaler = MinMaxScaler(feature_range=(-1, 1))
shifted_df_as_np = scaler.fit_transform(shifted_df_as_np)
# tableau_scaled
shifted_df_as_np
# Out:
# array([[ 0.24918585,  0.24336181, -0.18740532, -0.06295106, -0.3663852 ,
#          0.2837331 ],
#        [-0.42631461,  0.24918585,  0.24336181, -0.18740532, -0.06295106,
#         -0.3663852 ],
#        [-0.10616461, -0.42631461,  0.24918585,  0.24336181, -0.18740532,
#         -0.06295106],
#        ...,
#        [ 0.52823016,  0.58353469,  0.68595276,  0.78503296,  0.461173  ,
#          0.36994519],
#        [ 0.52300585,  0.52823016,  0.58353469,  0.68595276,  0.78503296,
#          0.461173  ],
#        [ 0.4423685 ,  0.52300585,  0.52823016,  0.58353469,  0.68595276,
#          0.78503296]])

# %%
# X = All the rows above without the first column
X = shifted_df_as_np[:, 1:]
# Predicter, all the rows but just the first column
y = shifted_df_as_np[:, 0]

X.shape, y.shape
# Out:
# ((522, 5), (522,))

# %%
# Make a deep copy but flipping it, to have the oldest value first
X = dc(np.flip(X, axis=1))
X
# Out:
# array([[ 0.2837331 , -0.3663852 , -0.06295106, -0.18740532,  0.24336181],
#        [-0.3663852 , -0.06295106, -0.18740532,  0.24336181,  0.24918585],
#        [-0.06295106, -0.18740532,  0.24336181,  0.24918585, -0.42631461],
#        ...,
#        [ 0.36994519,  0.461173  ,  0.78503296,  0.68595276,  0.58353469],
#        [ 0.461173  ,  0.78503296,  0.68595276,  0.58353469,  0.52823016],
#        [ 0.78503296,  0.68595276,  0.58353469,  0.52823016,  0.52300585]])

# %%
# Splitting to train and test 95% as train and 5% as test
split_index = int(len(X) * 0.95)

split_index
# Out:
# 495

# %%
# Up util the split index
X_train = X[:split_index]
# Split index onward
X_test = X[split_index:]

y_train = y[:split_index]
y_test = y[split_index:]

X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((495, 5), (27, 5), (495,), (27,))

# %%
# Requirement for PyTorch LSTM to have an extra dimension at the end
X_train = X_train.reshape((-1, lookback, 1))
X_test = X_test.reshape((-1, lookback, 1))

y_train = y_train.reshape((-1, 1))
y_test = y_test.reshape((-1, 1))

X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((495, 5, 1), (27, 5, 1), (495, 1), (27, 1))

# %%
# Wrap in pytorch tensor and make sure they are float
X_train = torch.tensor(X_train).float()
y_train = torch.tensor(y_train).float()
X_test = torch.tensor(X_test).float()
y_test = torch.tensor(y_test).float()

X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# (torch.Size([495, 5, 1]),
#  torch.Size([27, 5, 1]),
#  torch.Size([495, 1]),
#  torch.Size([27, 1]))

# %%
# We use dataset instead of tensor
from torch.utils.data import Dataset

# Custom class to transform the tensor to a dataset
class TimeSeriesDataset(Dataset):
    def __init__(self, X, y):
        self.X = X
        self.y = y

    def __len__(self):
        return len(self.X)

    def __getitem__(self, i):
        return self.X[i], self.y[i]

train_dataset = TimeSeriesDataset(X_train, y_train)
test_dataset = TimeSeriesDataset(X_test, y_test)

# %%
# Wrap the dataset in dataloader to get the batches
from torch.utils.data import DataLoader

# Batch size of 16
batch_size = 16

# Train dataloader with our train_dataset, we shuffle everytime
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
# The same but without shuffling
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %%
# Looping over our train_loader
for _, batch in enumerate(train_loader):
    # Get the x_batch and the y_batch to check the size
    x_batch, y_batch = batch[0].to(device), batch[1].to(device)
    print(x_batch.shape, y_batch.shape)
    break
# Out:
# torch.Size([16, 5, 1]) torch.Size([16, 1])

# %%
class LSTM(nn.Module):
    # Input size: number of features 1, hidden_size: However dimension we want in the middle could increase the overfitting,
    # num_stacked_layers: Stacked LSTM because they produce a sequence
    def __init__(self, input_size=1, hidden_size=64, num_stacked_layers=2, dropout_prob=0.2):
        super().__init__()
        self.hidden_size = hidden_size
        self.num_stacked_layers = num_stacked_layers

        self.lstm = nn.LSTM(input_size, hidden_size, num_stacked_layers,
                            batch_first=True)
        # After LSTM you want a fully connected layer map of our hidden size to 1 because at the end you just need the final closing value
        self.fc = nn.Linear(hidden_size, 1)

    def forward(self, x):
        # Batch size from the input, dynamiccaly
        batch_size = x.size(0)
        # Gates, initalize the LSTM with default h0 and c0
        h0 = torch.zeros(self.num_stacked_layers, batch_size, self.hidden_size).to(x.device)
        c0 = torch.zeros(self.num_stacked_layers, batch_size, self.hidden_size).to(x.device)
        # When you want to use the LSTM you pass those in the tuple, out = output, _ = updated tuple
        out, _ = self.lstm(x, (h0, c0))
        # The output has to pass in the fc layer
        out = self.fc(out[:, -1, :])
        return out

model = LSTM(1, 4, 1)
model.to(device)
model
# Out:
# LSTM(
#   (lstm): LSTM(1, 4, batch_first=True)
#   (fc): Linear(in_features=4, out_features=1, bias=True)
# )

# %%
def train_one_epoch():
    # Model to training mode
    model.train(True)
    print(f'Epoch: {epoch + 1}')
    # Start to accumulate the running_loss
    running_loss = 0.0

    # Loop over the train loader and get the batch_index and the batch
    for batch_index, batch in enumerate(train_loader):
        # Get x_batch and y_batch from the batch and put it on the device we're using
        x_batch, y_batch = batch[0].to(device), batch[1].to(device)

        # Getting the output from the model
        output = model(x_batch)
        # 'Tensor with one value' Getting the loss with the loss_function, comparing the output to the truth from the y_batch
        loss = loss_function(output, y_batch)
        # Incrementing the loss
        running_loss += loss.item()

        # Zero out the gradients
        optimizer.zero_grad()

        # Backward pass through the loss to calculate the gradient
        loss.backward()
        # Step in the direction of the gradient to upgrade our model
        optimizer.step()

        global_step = epoch * len(train_loader) + batch_index
        writer.add_scalar("Loss/Train", loss.item(), global_step)

        if batch_index % 10 == 9:  # print every 100 batches
            # Average loss across this 100 batches
            avg_loss_across_batches = running_loss / 100
            # writer.add_scalar('Train/Loss', avg_loss_across_batches, epoch * len(train_loader) + batch_index)
            print('Batch {0}, Loss: {1:.6f}'.format(batch_index+1,
                                                    avg_loss_across_batches))
            running_loss = 0.0
    print()

# %%
def validate_one_epoch():
    # Model to valuation mode
    model.train(False)
    running_loss = 0.0

    # Loop over the train loader and get the batch_index and the batch
    for batch_index, batch in enumerate(test_loader):
        # Get x_batch and y_batch from the batch and put it on the device we're using
        x_batch, y_batch = batch[0].to(device), batch[1].to(device)

        # No model update so we don't need to calculate the gradient
        with torch.no_grad():
            output = model(x_batch)
            loss = loss_function(output, y_batch)
            running_loss += loss.item()

    avg_loss_across_batches = running_loss / len(test_loader)
    writer.add_scalar("Loss/Validation", avg_loss_across_batches, epoch)

    print('Val Loss: {0:.3f}'.format(avg_loss_across_batches))
    print('***************************************************')
    print()

# %%
def log_graph_to_tensorboard():
    dummy_input = torch.zeros((1, lookback, 1)).to(device)
    writer.add_graph(model, dummy_input)
log_graph_to_tensorboard()

# %%
learning_rate = 0.002
num_epochs = 50
# Regression value because we calculate a continuous value to minimize the mean squared error
loss_function = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
# scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=2, gamma=0.5)
sample_input = torch.randn(1, lookback, 1).to(device)
writer.add_graph(model, sample_input)

for epoch in range(num_epochs):
    train_one_epoch()
    validate_one_epoch()
    # scheduler.step()
model_save_path = 'lstm_model.pth'
torch.save(model.state_dict(), model_save_path)
# Out:
# Epoch: 1
# Batch 10, Loss: 0.033826
# Batch 20, Loss: 0.025953
# Batch 30, Loss: 0.021046
#
# Val Loss: 0.499
# ***************************************************
#
# Epoch: 2
# Batch 10, Loss: 0.022672
# Batch 20, Loss: 0.017559
# Batch 30, Loss: 0.015996
#
# Val Loss: 0.351
# ***************************************************
#
# Epoch: 3
# Batch 10, Loss: 0.012782
# Batch 20, Loss: 0.012154
# Batch 30, Loss: 0.011814
#
# Val Loss: 0.226
# ***************************************************
#
# Epoch: 4
# Batch 10, Loss: 0.010075
# Batch 20, Loss: 0.009104
# Batch 30, Loss: 0.007203
#
# Val Loss: 0.143
# ***************************************************
#
# Epoch: 5
# Batch 10, Loss: 0.007506
# Batch 20, Loss: 0.006504
# Batch 30, Loss: 0.008459
#
# Val Loss: 0.103
# ***************************************************
#
# Epoch: 6
# Batch 10, Loss: 0.007416
# Batch 20, Loss: 0.006294
# Batch 30, Loss: 0.008133
#
# Val Loss: 0.093
# ***************************************************
#
# Epoch: 7
# Batch 10, Loss: 0.006108
# Batch 20, Loss: 0.007728
# Batch 30, Loss: 0.008120
#
# Val Loss: 0.087
# ***************************************************
#
# Epoch: 8
# Batch 10, Loss: 0.005844
# Batch 20, Loss: 0.007601
# Batch 30, Loss: 0.007982
#
# Val Loss: 0.086
# ***************************************************
#
# Epoch: 9
# Batch 10, Loss: 0.006647
# Batch 20, Loss: 0.007690
# Batch 30, Loss: 0.007228
#
# Val Loss: 0.084
# ***************************************************
#
# Epoch: 10
# Batch 10, Loss: 0.007609
# Batch 20, Loss: 0.007484
# Batch 30, Loss: 0.006673
#
# Val Loss: 0.084
# ***************************************************

# %%
# No gradient for the prediction
with torch.no_grad():
    # Give the model the first 95% of the train data then give it to the cpu because numpy only use the cpu
    predicted = model(X_train.to(device)).to('cpu').numpy()


# Plot the y_train, real closing data
plt.plot(y_train, label='Actual Close')
# Plot the predicted closing value
plt.plot(predicted, label='Predicted Close')
plt.xlabel('Day')
plt.ylabel('Return')
plt.legend()
plt.show()

# %%
# Flatten to making sure it's one axis
train_predictions = predicted.flatten()

dummies = np.zeros((X_train.shape[0], lookback+1))
dummies[:, 0] = train_predictions
# Inverse transform to transform the -1 1 to real dollar
dummies = scaler.inverse_transform(dummies)

train_predictions = dc(dummies[:, 0])
train_predictions
# Out:
# array([-14.97206254, -14.12860377, -17.73096825, -16.98250754,
#        -18.80387256, -20.87931986, -15.27997163, -17.05070264,
#        -14.44598473, -16.32550122, -17.03556247, -17.6782122 ,
#        -18.86708548, -18.65386387, -18.47993445, -16.74857101,
#        -13.31606729, -14.65107424, -11.08313413, -11.00528003,
#        -14.40494474, -10.93951105, -12.5680536 , -15.36598382,
#        -13.41214001, -13.26842337, -16.84754156, -19.60048658,
#        -16.84540262, -21.40442436, -19.10701778, -19.04021052,
#        -15.36170855, -16.08798984, -15.17104581, -16.3500262 ,
#        -13.05767466, -15.98640215, -17.0208966 , -16.94798181,
#        -16.1179908 , -17.13277353, -16.68849372, -16.55543277,
#        -14.39325077, -15.63902673, -17.50609425, -17.87156225,
#        -17.47922892, -19.24268418, -17.07814494, -18.25834553,
#        -17.79570155, -16.50290673, -14.32708935, -14.65548595,
#        -14.27098585, -14.58575617, -14.42732039, -13.9656861 ,
#        -14.40138158, -12.79835161, -15.0556759 , -16.94013299,
#        -14.30107128, -16.72352625, -16.07677927, -14.47512414,
#        -15.29049867, -11.63837863, -11.2962063 , -14.81755117,
#        -12.23302319, -14.41710782, -15.1337574 , -15.62244544,
#        -12.19694199, -14.37488011, -18.83555504, -18.67946871,
#        -14.56480735, -16.46499067, -15.91385381, -16.63229926,
#        -15.7488102 , -15.92083588, -14.69358523, -16.06402104,
#        -17.03156009, -15.39762212, -17.08255275, -16.74324057,


# %%
plt.plot(new_y_test, label='Actual Close')
plt.plot(test_predictions, label='Predicted Close')
plt.xlabel('Day')
plt.ylabel('Close')
plt.legend()
plt.show()

# %%
def log_predictions_to_tensorboard(y_actual, y_predicted, title, step):
    fig, ax = plt.subplots()
    ax.plot(y_actual, label='Actual Close')
    ax.plot(y_predicted, label='Predicted Close')
    ax.set_xlabel('Day')
    ax.set_ylabel('Close')
    ax.legend()
    writer.add_figure(title, fig, global_step=step)

# %%
log_predictions_to_tensorboard(new_y_train, train_predictions, "Train Predictions", epoch)
log_predictions_to_tensorboard(new_y_test, test_predictions, "Test Predictions", epoch)

# %%
loaded_model = LSTM(1, 4, 1)
loaded_model.load_state_dict(torch.load(model_save_path))
loaded_model.to(device)
loaded_model.eval()
# Out:
# /var/folders/8t/zq98g53s2rs8x1qgc3h02m100000gn/T/ipykernel_22093/706240240.py:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   loaded_model.load_state_dict(torch.load(model_save_path))
# LSTM(
#   (lstm): LSTM(1, 4, batch_first=True)
#   (fc): Linear(in_features=4, out_features=1, bias=True)
# )

# %%
def predict_future_values(model, initial_sequence, n_future_steps, lookback):
    """
    Prédit les valeurs futures en utilisant le modèle LSTM.
    
    Arguments:
    - model: le modèle LSTM entraîné.
    - initial_sequence: la séquence initiale utilisée pour prédire les valeurs futures.
    - n_future_steps: le nombre de pas dans le futur à prédire.
    - lookback: la taille de la fenêtre glissante.
    
    Retourne:
    - Une liste des prédictions futures.
    """
    model.eval()
    predictions = []
    
    # Assurez-vous que la séquence initiale est un tenseur 3D [batch_size, lookback, features]
    input_seq = initial_sequence.reshape(1, lookback, 1).to(device)

    with torch.no_grad():
        for _ in range(n_future_steps):
            # Obtenir la prédiction pour l'étape suivante
            pred = model(input_seq)
            predictions.append(pred.item())
            
            # Mettre à jour la séquence en supprimant le plus ancien et en ajoutant la prédiction
            new_input = pred.reshape(1, 1, 1)  # Forme [batch_size, 1, features]
            input_seq = torch.cat((input_seq[:, 1:, :], new_input), dim=1)
    
    return predictions

# %%
initial_sequence = X_test[-1]

# Prédire les valeurs futures
future_predictions = predict_future_values(loaded_model, initial_sequence, 1, lookback)

# %%
dummies = np.zeros((len(future_predictions), lookback + 1))
dummies[:, 0] = future_predictions
dummies = scaler.inverse_transform(dummies)
future_predictions = dummies[:, 0]

# %%
last_date = data['Year-Month'].iloc[-1]
future_dates = pd.date_range(last_date + pd.offsets.MonthBegin(), periods=1, freq='MS')

future_df = pd.DataFrame({'Year-Month': future_dates, 'Predicted Return': future_predictions})
print(future_df)
# Out:
#   Year-Month  Predicted Return
# 0 2024-11-01         -8.985414

# %%
def log_table_to_tensorboard(df, title, step):
    """
    Loggue un tableau Pandas sous forme de texte dans TensorBoard.
    
    Arguments :
    - df : DataFrame à logger
    - title : Titre pour la section dans TensorBoard
    - step : Étape actuelle pour le suivi
    """
    # Convertir le DataFrame en texte formaté
    table_text = df.to_string(index=False)
    
    # Ajout au logger TensorBoard
    writer.add_text(title, f"```\n{table_text}\n```", global_step=step)

print(future_df)
log_table_to_tensorboard(future_df, 'Future Predictions', epoch)

# Fermer TensorBoard
writer.close()
# Out:
#   Year-Month  Predicted Return
# 0 2024-11-01         -8.985414
